# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
# a = 

a = pd.Series([100,200,300,400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
print(type(a))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
import pandas._libs.indexing
from numpy import e
a[2]
# Out:
# np.int64(300)

# %% [markdown]
# What are the values of index for series a?

# %%
a.values
# Out:
# array([100, 200, 300, 400])

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ['c','a','b','d']

# %% [markdown]
# Access the value in the series with index 'd'

# %%
a['d']
# Out:
# np.int64(400)

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
a.sort_index()
# Out:
# a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
# b = 

b = pd.Series([800,450,100])
b.index = ["e","f","g"]
b
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
# a =

a = pd.concat([a,b])

# %%
#print a again after appending b into it

a
# Out:
# c    100
# a    200
# b    300
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
# a = 
asort = a.sort_values(ascending=True)

# %%
asort
# Out:
# c    100
# g    100
# a    200
# b    300
# d    400
# f    450
# e    800
# dtype: int64

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
# df = 
df = pd.DataFrame(a)

# %%
df
# Out:
#      0
# c  100
# a  200
# b  300
# d  400
# e  800
# f  450
# g  100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
df.shape
# Out:
# (7, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
# yep its same as the series.

df.index
# Out:
# Index(['c', 'a', 'b', 'd', 'e', 'f', 'g'], dtype='object')

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
df.head()

# It will show first 5 rows of the data
# Out:
#      0
# c  100
# a  200
# b  300
# d  400
# e  800

# %%
df.tail()

# it will show last 5 rows
# Out:
#      0
# b  300
# d  400
# e  800
# f  450
# g  100

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df.columns= ['points']

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
#Create fruits array

# fruits =

fruits = ['orange', 'mango', 'apple']
fruits_array = np.random.choice(fruits, size=7)
print(fruits_array)
# Out:
# ['mango' 'orange' 'mango' 'orange' 'orange' 'orange' 'mango']

# %%
#Create series fruits out of fruits array
fruits = pd.Series(fruits_array)
fruits
# Out:
# 0     mango
# 1    orange
# 2     mango
# 3    orange
# 4    orange
# 5    orange
# 6     mango
# dtype: object

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruits.index = df.index
fruits
# Out:
# c     mango
# a    orange
# b     mango
# d    orange
# e    orange
# f    orange
# g     mango
# dtype: object

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df["fruits"] = fruits

print(df)
# Out:
#    points  fruits
# c     100   mango
# a     200  orange
# b     300   mango
# d     400  orange
# e     800  orange
# f     450  orange
# g     100   mango

# %%
df.head()
# Out:
#    points  fruits
# c     100   mango
# a     200  orange
# b     300   mango
# d     400  orange
# e     800  orange

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
# d1 = 
d1 = pd.DataFrame({
    "city" : ["Chandigarh", "Delhi", "Kanpur", "Chennai", "Manali" ],
    "Temperature" : [15, 22, 20, 26,-2]
})

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
d1.shape
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city = d1['city']
city
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)
print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
# d2 = 

d2 = pd.DataFrame({
    "city":["Bengaluru", "Coimbatore", "Srirangam", "Pondicherry"],
    "Temperature":[24,35,36,39]
})

# %% [markdown]
# print the shape of this dataframe

# %%
d2.shape
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
# d3 = 
d3 = pd.concat([d1,d2], ignore_index=True)
d3
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 5    Bengaluru           24
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
lesstemp20 = d3[d3['Temperature'] <= 20]
display(lesstemp20)
print(f"Number of cities with temp <= 20: {len(lesstemp20)}")
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2
# Number of cities with temp <= 20: 3

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
greaterthen30 = d3[d3['Temperature'] >= 30]
greaterthen30
# Out:
#           city  Temperature
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
# write function here

# def is_ut(x):
    
#     # write code below
    
# d3['is_ut'] = 

def is_ut(city):
    ut_city = ["Chandigarh","Pondicherry","Delhi"]
    return city in ut_city

d3['is_ut'] = d3['city'].apply(is_ut)

d3
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 5    Bengaluru           24  False
# 6   Coimbatore           35  False
# 7    Srirangam           36  False
# 8  Pondicherry           39   True

# %%
# print d3

print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 5    Bengaluru           24  False
# 6   Coimbatore           35  False
# 7    Srirangam           36  False
# 8  Pondicherry           39   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
# write function here

def c_to_f(c):
    return (c * 9/5) + 32

# %%
# check function c_to_f(10)
print(f"Test: c_to_f(10) = {c_to_f(10)}")
# Out:
# Test: c_to_f(10) = 50.0

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'

d3['temp_farenhiet'] = d3['Temperature'].apply(c_to_f)
display(d3)
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 0   Chandigarh           15   True            59.0
# 1        Delhi           22   True            71.6
# 2       Kanpur           20  False            68.0
# 3      Chennai           26  False            78.8
# 4       Manali           -2  False            28.4
# 5    Bengaluru           24  False            75.2
# 6   Coimbatore           35  False            95.0
# 7    Srirangam           36  False            96.8
# 8  Pondicherry           39   True           102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
subset_ut = d1[d1['city'].isin(['Chandigarh', 'Delhi'])]

subset_ut
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
subset_hot = d1[d1['Temperature'] > 90]
subset_hot
# Out:
# Empty DataFrame
# Columns: [city, Temperature]
# Index: []

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
first_three_rows = d1.head(3)
print(first_three_rows)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
# select all the rows and last two columns in the dataframe. 
subset_last_two_cols = d1.iloc[:, -2:]

subset_last_two_cols
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26

# %% [markdown]
# ## Groupby

# %%
# Create a dataframe using dictionary of your choice

# data = 
data = {
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Age": [25, 30, 35, 40],
    "City": ["New York", "Los Angeles", "Chicago", "Houston"]
}

# %%
# Use Groupby of single column with aggregate sum()

data_df = pd.DataFrame(data)
data_df.groupby('City').sum()
# Out:
#                 Name  Age
# City
# Chicago      Charlie   35
# Houston        David   40
# Los Angeles      Bob   30
# New York       Alice   25

# %%
# Use Groupby of single column with aggregate count()
data_df.groupby('City').count()
# Out:
#              Name  Age
# City
# Chicago         1    1
# Houston         1    1
# Los Angeles     1    1
# New York        1    1

# %%
# Use Groupby of single column with aggregate min() and max()

data_df.groupby('City').min()
# Out:
#                 Name  Age
# City
# Chicago      Charlie   35
# Houston        David   40
# Los Angeles      Bob   30
# New York       Alice   25

# %%
data_df.groupby('City').max()
# Out:
#                 Name  Age
# City
# Chicago      Charlie   35
# Houston        David   40
# Los Angeles      Bob   30
# New York       Alice   25

# %%
# Use Groupby of any 2 columns with aggregate mean()
data_df.groupby(['City', 'Name']).mean()
# Out:
#                       Age
# City        Name
# Chicago     Charlie  35.0
# Houston     David    40.0
# Los Angeles Bob      30.0
# New York    Alice    25.0

# %%
# Use Groupby of any 2 columns with aggregate min() and max()

data_df.groupby(['City', 'Name']).min()
# Out:
#                      Age
# City        Name
# Chicago     Charlie   35
# Houston     David     40
# Los Angeles Bob       30
# New York    Alice     25

# %%
data_df.groupby(['City', 'Name']).max()
# Out:
#                      Age
# City        Name
# Chicago     Charlie   35
# Houston     David     40
# Los Angeles Bob       30
# New York    Alice     25

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
# a = 
a = pd.date_range(start='2020-01-01', end='2021-04-01')

# %% [markdown]
# print a

# %%
a
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[ns]', length=457, freq='D')

# %% [markdown]
# What is the len of a?

# %%
len(a)
# Out:
# 457

# %% [markdown]
# What is the type of a?

# %%
type(a)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex
